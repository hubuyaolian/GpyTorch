# %% [markdown]
# # Week10 检测：词嵌入、GRU、文本生成与 Seq2Seq
#
# > 本检测涵盖 Day06-Day10 的核心知识点，共 20 道选择题，每题 5 分，满分 100 分。

# %%
answers = {i: '' for i in range(1, 21)}

# %% [markdown]
# ---
#
# ## 第一部分：词嵌入（Day06）
#
# ### 第 1 题
#
# 独热编码的主要缺陷是什么？
#
# - A. 编码长度太短
# - B. 所有词距离相等，无法表达语义关系
# - C. 只能编码中文
# - D. 计算速度太慢
#
# ### 第 2 题
#
# 词嵌入（Word2Vec）的核心思想是什么？
#
# - A. 用独热编码表示每个词
# - B. 把词映射到低维稠密向量，语义相近的词在向量空间中靠近
# - C. 用哈希函数给每个词分配编号
# - D. 按词频排序给每个词分配坐标
#
# ### 第 3 题
#
# 在 PyTorch 中，词嵌入使用什么模块？
#
# - A. nn.Linear
# - B. nn.Embedding(vocab_size, embedding_dim)
# - C. nn.Conv1d
# - D. nn.LSTM
#
# ### 第 4 题
#
# LSTM 文本分类的典型流程是什么？
#
# - A. LSTM → Embedding → FC → Sigmoid
# - B. Embedding → LSTM → FC → Sigmoid
# - C. FC → Embedding → LSTM → Sigmoid
# - D. Sigmoid → LSTM → Embedding → FC
#
# ## 第二部分：GRU（Day07）
#
# ### 第 5 题
#
# GRU 有几个门？
#
# - A. 1 个
# - B. 2 个
# - C. 3 个
# - D. 4 个
#
# ### 第 6 题
#
# GRU 的两个门分别是什么？
#
# - A. 遗忘门和输入门
# - B. 重置门和更新门
# - C. 查询门和键门
# - D. 编码门和解码门
#
# ### 第 7 题
#
# GRU 的更新公式 h_t = z_t ⊙ h_{t-1} + (1-z_t) ⊙ h̃_t 体现了什么关键特性？
#
# - A. 乘法更新导致梯度消失
# - B. 加法更新，和 LSTM、ResNet 一样让梯度保底
# - C. 只使用当前输入，忽略历史
# - D. 完全遗忘旧记忆
#
# ### 第 8 题
#
# GRU 相比 LSTM 参数量大约减少多少？
#
# - A. 1/2
# - B. 1/3
# - C. 2/3
# - D. 9/10
#
# ### 第 9 题
#
# 什么场景下更推荐使用 GRU 而非 LSTM？
#
# - A. 数据量大、序列很长
# - B. 数据量小、追求速度
# - C. 需要最高精度
# - D. 处理图像数据
#
# ## 第三部分：文本生成（Day08）
#
# ### 第 10 题
#
# 字符级语言模型的核心思路是什么？
#
# - A. 一次生成整段文本
# - B. 逐字预测下一个字符
# - C. 按词预测下一个词
# - D. 按句子预测下一个句子
#
# ### 第 11 题
#
# 温度参数的作用是什么？
#
# - A. 控制训练速度
# - B. 控制 softmax 输出的概率分布尖锐程度
# - C. 控制网络深度
# - D. 控制学习率
#
# ### 第 12 题
#
# 温度很低（如 0.1）时，生成的文本有什么特点？
#
# - A. 非常随机混乱
# - B. 几乎重复训练文本，保守但缺乏创意
# - C. 语法错误很多
# - D. 生成速度最快
#
# ### 第 13 题
#
# 温度很高（如 2.0）时，生成的文本有什么特点？
#
# - A. 几乎重复训练文本
# - B. 语法完美但内容无聊
# - C. 非常随机，可能乱七八糟
# - D. 生成速度最慢
#
# ## 第四部分：Seq2Seq（Day09）
#
# ### 第 14 题
#
# Seq2Seq 的架构由哪两部分组成？
#
# - A. Embedding 和 Classifier
# - B. Encoder 和 Decoder
# - C. Generator 和 Discriminator
# - D. Teacher 和 Student
#
# ### 第 15 题
#
# Encoder 在 Seq2Seq 中的作用是什么？
#
# - A. 生成目标语言
# - B. 把源语言「压缩」成上下文向量
# - C. 计算损失函数
# - D. 调整学习率
#
# ### 第 16 题
#
# Seq2Seq 的致命瓶颈是什么？
#
# - A. 训练速度太慢
# - B. 整个源句子被压缩成固定长度向量，长句子信息严重丢失
# - C. 只能处理短句子
# - D. 无法反向传播
#
# ### 第 17 题
#
# Seq2Seq 的信息瓶颈问题引出了什么重要机制？
#
# - A. 残差连接
# - B. 注意力机制
# - C. 批归一化
# - D. Dropout
#
# ### 第 18 题
#
# Sutskever 在哪一年首次用 Encoder-Decoder 实现神经机器翻译？
#
# - A. 2012 年
# - B. 2014 年
# - C. 2017 年
# - D. 2020 年
#
# ## 第五部分：收官实战（Day10）
#
# ### 第 19 题
#
# GRU 的重置门（reset gate）控制什么？
#
# - A. 从细胞状态中读多少信息
# - B. 计算新候选隐藏状态时忽略多少旧记忆
# - C. 写多少新信息
# - D. 输出多少到下一层
#
# ### 第 20 题
#
# LSTM 文本分类中，通常取哪个状态作为整个序列的表示送入分类器？
#
# - A. 第一个时间步的隐藏状态
# - B. 最后一个时间步的隐藏状态
# - C. 所有时间步隐藏状态的平均
# - D. 隐藏状态的最大值

# %% [markdown]
# ---
#
# ## 评分区

# %%
correct_answers = {
    1: 'B', 2: 'B', 3: 'B', 4: 'B', 5: 'B',
    6: 'B', 7: 'B', 8: 'B', 9: 'B', 10: 'B',
    11: 'B', 12: 'B', 13: 'C', 14: 'B', 15: 'B',
    16: 'B', 17: 'B', 18: 'B', 19: 'B', 20: 'B',
}
score = sum(5 for q in correct_answers if answers.get(q,'').strip().upper() == correct_answers[q])
wrong = [(q, correct_answers[q], answers.get(q,'').strip().upper()) for q in correct_answers if answers.get(q,'').strip().upper() != correct_answers[q]]
print(f"{'='*50}\n  Week10 检测成绩\n{'='*50}")
print(f"  得分：{score} / 100")
print(f"  正确：{score//5} / 20\n{'='*50}")
if wrong:
    print(f"\n  错题解析：\n  {'-'*46}")
    for q, c, u in wrong: print(f"  第{q:2d}题：你的答案 {u or '(未作答)'}  |  正确答案 {c}")
    print(f"  {'-'*46}")
if score == 100: print(f"\n  全部正确！Week10 掌握扎实！")
elif score >= 80: print(f"\n  不错！大部分知识点已掌握。")
elif score >= 60: print(f"\n  及格，但需要回顾错题对应内容。")
else: print(f"\n  需要加油！建议重学 Week10。")
