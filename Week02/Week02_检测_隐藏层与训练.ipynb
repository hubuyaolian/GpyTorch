# %% [markdown]
# # Week02 检测：隐藏层、激活函数与训练
#
# > 本检测涵盖 Day01-Day05 的核心知识点，共 20 道选择题，每题 5 分，满分 100 分。

# %%
answers = {i: '' for i in range(1, 21)}

# %% [markdown]
# ---
#
# ## 第一部分：隐藏层（Day01）
#
# ### 第 1 题
#
# 隐藏层为什么能让神经网络解决 XOR 问题？
#
# - A. 隐藏层增加了更多参数，模型更强大
# - B. 隐藏层对输入空间做非线性变换，使变换后的空间线性可分
# - C. 隐藏层自动选择最优激活函数
# - D. 隐藏层减少了参数数量，训练更快
#
# ### 第 2 题
#
# 关于隐藏层的几何直觉，以下说法正确的是？
#
# - A. 隐藏层在原空间中画曲线边界
# - B. 隐藏层做空间变换，输出层在新空间中画直线
# - C. 隐藏层直接输出分类结果
# - D. 隐藏层只增加计算量，不改变空间结构
#
# ### 第 3 题
#
# 解决 XOR 问题的最小 MLP 架构是什么？
#
# - A. 2-1-1（2输入-1隐藏-1输出）
# - B. 2-2-1（2输入-2隐藏-1输出）
# - C. 2-3-1（2输入-3隐藏-1输出）
# - D. 2-4-1（2输入-4隐藏-1输出）
#
# ### 第 4 题
#
# 如果没有激活函数，多层隐藏层等价于什么？
#
# - A. 一个更深的非线性网络
# - B. 一个单层线性网络
# - C. 一个决策树
# - D. 一个支持向量机
#
# ## 第二部分：激活函数（Day02）
#
# ### 第 5 题
#
# Sigmoid 函数 σ(x) = 1/(1+e^(-x)) 的最大导数值是多少？
#
# - A. 1.0
# - B. 0.5
# - C. 0.25
# - D. 0.1
#
# ### 第 6 题
#
# ReLU 函数的主要优点是什么？
#
# - A. 输出范围在 (0,1) 之间，适合概率输出
# - B. 正区间梯度恒为 1，缓解梯度消失
# - C. 负区间也有非零梯度，不会丢失信息
# - D. 输出以零为中心，训练更稳定
#
# ### 第 7 题
#
# 什么是「死亡 ReLU」问题？
#
# - A. ReLU 的输出太大导致数值溢出
# - B. 当输入持续为负时，梯度为 0，神经元可能永久失活
# - C. ReLU 函数不可导，无法反向传播
# - D. ReLU 在正区间梯度消失
#
# ### 第 8 题
#
# tanh 相比 Sigmoid 的主要优势是什么？
#
# - A. 计算速度更快
# - B. 输出以零为中心
# - C. 没有梯度消失问题
# - D. 输出范围更大
#
# ## 第三部分：反向传播（Day03）
#
# ### 第 9 题
#
# 反向传播的本质是什么？
#
# - A. 从输入到输出计算预测值
# - B. 链式法则的自动化应用，实现「信用分配」
# - C. 随机调整权重直到模型收敛
# - D. 用遗传算法优化网络参数
#
# ### 第 10 题
#
# 在 PyTorch 中，如何让一个张量参与自动求导？
#
# - A. 调用 tensor.grad()
# - B. 设置 requires_grad=True，然后调用 loss.backward()
# - C. 使用 torch.no_grad() 上下文
# - D. 将张量转换为 NumPy 数组
#
# ## 第四部分：MLP 与训练（Day04-Day05）
#
# ### 第 11 题
#
# 在 PyTorch 中，`nn.Linear(4, 3)` 创建的层有什么参数？
#
# - A. 4 个权重和 3 个偏置
# - B. 4×3=12 个权重和 3 个偏置
# - C. 3×4=12 个权重和 4 个偏置
# - D. 7 个参数（4+3）
#
# ### 第 12 题
#
# 二分类问题通常使用什么损失函数？
#
# - A. MSE（均方误差）
# - B. MAE（平均绝对误差）
# - C. BCE（二元交叉熵）
# - D. CrossEntropy（交叉熵）
#
# ### 第 13 题
#
# Adam 优化器相比 SGD 的主要优势是什么？
#
# - A. 计算量更小
# - B. 自适应学习率，对不同参数自动调整步长
# - C. 保证找到全局最优解
# - D. 不需要设置学习率
#
# ### 第 14 题
#
# 学习率设置太大会导致什么问题？
#
# - A. 收敛太慢
# - B. 在最优点附近震荡甚至发散
# - C. 梯度消失
# - D. 过拟合
#
# ### 第 15 题
#
# SGD + Momentum 相比普通 SGD 的改进是什么？
#
# - A. 自动调整学习率
# - B. 累积历史梯度方向，减少震荡、加速收敛
# - C. 增加正则化防止过拟合
# - D. 使用二阶导数信息
#
# ### 第 16 题
#
# MLP 的标准训练循环顺序是什么？
#
# - A. 反向传播 → 前向传播 → 计算损失 → 更新参数
# - B. 前向传播 → 计算损失 → 反向传播 → 更新参数
# - C. 更新参数 → 前向传播 → 反向传播 → 计算损失
# - D. 计算损失 → 前向传播 → 更新参数 → 反向传播
#
# ### 第 17 题
#
# MSE 损失函数的公式是什么？
#
# - A. (1/n)Σ|y - ŷ|
# - B. (1/n)Σ(y - ŷ)²
# - C. -[y·log(ŷ) + (1-y)·log(1-ŷ)]
# - D. -Σy·log(ŷ)
#
# ### 第 18 题
#
# 关于梯度下降的局部最小值问题，以下说法正确的是？
#
# - A. 局部最小值是深度学习中最严重的问题
# - B. 在高维问题中，局部最小值通常足够好，不是主要障碍
# - C. Adam 优化器可以完全避免局部最小值
# - D. 增加网络深度可以消除局部最小值
#
# ### 第 19 题
#
# 链式法则在三层网络中的梯度传播公式是什么？
#
# - A. ∂L/∂w1 = ∂L/∂y + ∂y/∂h + ∂h/∂w1
# - B. ∂L/∂w1 = ∂L/∂y × ∂y/∂h × ∂h/∂w1
# - C. ∂L/∂w1 = ∂L/∂y / (∂y/∂h × ∂h/∂w1)
# - D. ∂L/∂w1 = max(∂L/∂y, ∂y/∂h, ∂h/∂w1)
#
# ### 第 20 题
#
# Sigmoid 函数的输出非零中心会导致什么问题？
#
# - A. 梯度爆炸
# - B. 后续层的输入总是正的，梯度更新呈 zigzag 震荡，收敛变慢
# - C. 无法进行反向传播
# - D. 输出值超出有效范围

# %% [markdown]
# ---
#
# ## 评分区

# %%
correct_answers = {
    1: 'B', 2: 'B', 3: 'B', 4: 'B', 5: 'C',
    6: 'B', 7: 'B', 8: 'B', 9: 'B', 10: 'B',
    11: 'B', 12: 'C', 13: 'B', 14: 'B', 15: 'B',
    16: 'B', 17: 'B', 18: 'B', 19: 'B', 20: 'B',
}
score = sum(5 for q in correct_answers if answers.get(q,'').strip().upper() == correct_answers[q])
wrong = [(q, correct_answers[q], answers.get(q,'').strip().upper()) for q in correct_answers if answers.get(q,'').strip().upper() != correct_answers[q]]
print(f"{'='*50}\n  Week02 检测成绩\n{'='*50}")
print(f"  得分：{score} / 100")
print(f"  正确：{score//5} / 20\n{'='*50}")
if wrong:
    print(f"\n  错题解析：\n  {'-'*46}")
    for q, c, u in wrong: print(f"  第{q:2d}题：你的答案 {u or '(未作答)'}  |  正确答案 {c}")
    print(f"  {'-'*46}")
if score == 100: print(f"\n  全部正确！Week02 掌握扎实！")
elif score >= 80: print(f"\n  不错！大部分知识点已掌握。")
elif score >= 60: print(f"\n  及格，但需要回顾错题对应内容。")
else: print(f"\n  需要加油！建议重学 Week02。")
